# %% [markdown]
# Title
# =====
#
# markdown cell
#
# ```{note}
# test note. collab?
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
plt.plot(x, np.sin(x))
plt.xlabel("x")
plt.ylabel("y");
